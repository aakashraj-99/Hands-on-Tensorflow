# %% [markdown]
# <a href="https://colab.research.google.com/github/aakashraj-99/Hands-on-Tensorflow/blob/master/Housing_prices.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

def house_model(y_new):
    xs = np.array([0,1,2,3,4,5],dtype = int)
    ys = np.array([0.5,1.0,1.5,2.0,2.5,3.0],dtype = float)
    model = tf.keras.Sequential([keras.layers.Dense(units = 1 , input_shape=[1])])
    model.compile(optimizer = 'sgd' , loss = 'mean_squared_error')
    model.fit(xs,ys,epochs=500)
    return model.predict(y_new)[0]

prediction = house_model([7.0])
print(prediction)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 223ms/step - loss: 39.4991
# Epoch 2/500
# 1/1 [==============================] - 0s 3ms/step - loss: 25.4427
# Epoch 3/500
# 1/1 [==============================] - 0s 7ms/step - loss: 16.3885
# Epoch 4/500
# 1/1 [==============================] - 0s 5ms/step - loss: 10.5565
# Epoch 5/500
# 1/1 [==============================] - 0s 6ms/step - loss: 6.7999
# Epoch 6/500
# 1/1 [==============================] - 0s 5ms/step - loss: 4.3802
# Epoch 7/500
# 1/1 [==============================] - 0s 7ms/step - loss: 2.8216
# Epoch 8/500
# 1/1 [==============================] - 0s 5ms/step - loss: 1.8177
# Epoch 9/500
# 1/1 [==============================] - 0s 5ms/step - loss: 1.1710
# Epoch 10/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.7545
# Epoch 11/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.4861
# Epoch 12/500
# 1/1 [==============================] - 0s 6ms/step - loss: 0.3133
# ...
